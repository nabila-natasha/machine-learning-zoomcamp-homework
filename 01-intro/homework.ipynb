# %% [markdown]
# # Homework 1

# %% [markdown]
# ## Q1. Pandas version

# %%
pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# ## Getting the data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv')

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# 4          17.5                 31.0

# %% [markdown]
# ## Q2. Records count

# %%
df.shape
# Out:
# (10000, 11)

# %% [markdown]
# ## Q3. Fuel types

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %% [markdown]
# ## Q4. Missing values

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %% [markdown]
# ## Q5. Max fuel efficiency

# %%
df['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %% [markdown]
# ## Q6. Median value of horsepower

# %% [markdown]
# 1. Find the median value of the `horsepower` column in the dataset.

# %%
df['horsepower'].median()
# Out:
# np.float64(254.0)

# %%
df.describe().round(3)
# Out:
#        model_year  num_doors  engine_displacement  num_cylinders  horsepower  \
# count   10000.000  10000.000            10000.000      10000.000    9123.000
# mean     1999.550      3.504             2268.807          6.035     254.446
# std        14.208      0.952              183.447          0.543      22.845
# min      1975.000      2.000             1590.000          4.000     171.000
# 25%      1987.000      3.000             2150.000          6.000     239.000
# 50%      2000.000      4.000             2270.000          6.000     254.000
# 75%      2012.000      4.000             2390.000          6.000     270.000
# max      2024.000      5.000             3110.000          8.000     334.000
#
#        vehicle_weight  acceleration  fuel_efficiency_mpg
# count       10000.000      9736.000            10000.000
# mean         4286.754        18.888               29.998
# std           266.212         1.280                2.930
# min          3320.000        14.000               19.800
# 25%          4110.000        18.000               28.000
# 50%          4280.000        18.900               30.000
# 75%          4470.000        19.700               31.900
# max          5460.000        23.800               41.200

# %% [markdown]
# 2. Next, calculate the most frequent value of the same `horsepower` column.

# %%
most_frequent_hp = df['horsepower'].mode()[0]

# %%
most_frequent_hp
# Out:
# np.float64(252.0)

# %% [markdown]
# 3. Use the `fillna` method to fill the missing values in the `horsepower` column with the most frequent value from the previous step.

# %%
df['horsepower'] = df['horsepower'].fillna(most_frequent_hp)

# %%
df['horsepower'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 4. Now, calculate the median value of `horsepower` once again.

# %%
df['horsepower'].median()
# Out:
# np.float64(252.0)

# %% [markdown]
# ## Q7. Sum of weights

# %% [markdown]
# 1. Select all the cars from Asia

# %%
asia_cars = df[df['origin'] == 'Asia']

# %%
asia_cars
# Out:
#       model_year origin fuel_type         drivetrain  num_doors  \
# 2           1996   Asia  Gasoline  Front-wheel drive          5
# 6           1992   Asia  Gasoline  Front-wheel drive          2
# 8           1997   Asia  Gasoline   Rear-wheel drive          3
# 10          1978   Asia  Gasoline    All-wheel drive          3
# 15          2007   Asia    Diesel  Front-wheel drive          4
# ...          ...    ...       ...                ...        ...
# 9984        2011   Asia  Gasoline  Front-wheel drive          3
# 9987        2004   Asia    Diesel    All-wheel drive          3
# 9990        1975   Asia    Diesel  Front-wheel drive          4
# 9994        1993   Asia  Gasoline   Rear-wheel drive          2
# 9996        1993   Asia  Gasoline    All-wheel drive          2
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 2                    2320              6       267.0            4240
# 6                    2270              6       250.0            4310
# 8                    2330              6       251.0            4230
# 10                   2410              6       252.0            4420
# 15                   2170              5       226.0            3950
# ...                   ...            ...         ...             ...
# 9984                 2410              6       256.0            4610
# 9987                 2180              6       266.0            4530
# 9990                 1940              6       236.0            3630
# 9994                 2360              6       257.0            4610
# 9996                 2300              6       244.0            4370
#
#       acceleration  fuel_efficiency_mpg
# 2             17.3                 27.5
# 6             21.7                 26.8
# 8             19.5                 30.9
# 10            19.5                 26.8
# 15            18.0                 35.4
# ...            ...                  ...
# 9984          20.2                 32.4
# 9987          18.6                 29.0
# 9990          19.7                 32.4
# 9994          22.2                 30.1
# 9996          19.0                 30.0
#
# [2994 rows x 11 columns]

# %% [markdown]
# 2. Select only columns `vehicle_weight` and `model_year`

# %%
asia_cars_subset = asia_cars[['vehicle_weight', 'model_year']]

# %%
asia_cars_subset
# Out:
#       vehicle_weight  model_year
# 2               4240        1996
# 6               4310        1992
# 8               4230        1997
# 10              4420        1978
# 15              3950        2007
# ...              ...         ...
# 9984            4610        2011
# 9987            4530        2004
# 9990            3630        1975
# 9994            4610        1993
# 9996            4370        1993
#
# [2994 rows x 2 columns]

# %% [markdown]
# 3. Select the first 7 values

# %%
asia_cars_first_7 = asia_cars_subset.head(7)
asia_cars_first_7
# Out:
#     vehicle_weight  model_year
# 2             4240        1996
# 6             4310        1992
# 8             4230        1997
# 10            4420        1978
# 15            3950        2007
# 16            4750        2021
# 22            4450        2019

# %% [markdown]
# 4. Get the underlying NumPy array. Let's call it `X`.

# %%
import numpy as np

# %%
X = asia_cars_first_7.values
X
# Out:
# array([[4240, 1996],
#        [4310, 1992],
#        [4230, 1997],
#        [4420, 1978],
#        [3950, 2007],
#        [4750, 2021],
#        [4450, 2019]])

# %% [markdown]
# 5. Compute matrix-matrix multiplication between the transpose of `X` and `X`. To get the transpose, use `X.T`. Let's call the result `XTX`.

# %%
XTX = X.T.dot(X)
XTX
# Out:
# array([[131950500,  60750580],
#        [ 60750580,  28041424]])

# %% [markdown]
# 6. Invert `XTX`.

# %%
XTX_inv = np.linalg.inv(XTX)
XTX_inv
# Out:
# array([[ 2.96830537e-06, -6.43071025e-06],
#        [-6.43071025e-06,  1.39675281e-05]])

# %% [markdown]
# 7. Create an array `y` with values `[1100, 1300, 800, 900, 1000, 1100, 1200]`.

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %% [markdown]
# 8. Multiply the inverse of `XTX` with the transpose of `X`, and then multiply the result by `y`. Call the result `w`.

# %%
w = XTX_inv.dot(X.T).dot(y)
w
# Out:
# array([0.13644777, 0.2327492 ])

# %% [markdown]
# 9. What's the sum of all the elements of the result?

# %%
ans = w.sum()

# %%
print("Sum of all elements:", ans.round(3))
# Out:
# Sum of all elements: 0.369
